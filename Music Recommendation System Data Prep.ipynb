# %% [markdown]
# ## Music Recommendation Algorithm
#
# In this task, the goal is to predict the chances of a user listening to a song repetitively after the first observable listening event within a time window was triggered. If there are recurring listening event(s) triggered within a month after the user’s very first observable listening event, its target is marked 1, and 0 otherwise in the training set.
# The two datasets used in  this project are the KKBOX and Spotify datasets.
#
# ### KKBOX Data
#
# KKBOX provides a training data set which consists of information of the first observable listening event for each unique user-song pair within a specific time duration. Metadata of each unique user and song pair is also provided.
#
# Tables
# #### main.csv
# * msno: user id
# * song_id: song id
# * source_system_tab: the name of the tab where the event was triggered. System tabs are used to categorize KKBOX mobile apps functions. For example, tab my library contains functions to manipulate the local storage, and tab search contains functions relating to search.
# * source_screen_name: name of the layout a user sees.
# * source_type: an entry point a user first plays music on mobile apps. An entry point could be album, online-playlist, song .. etc.
# * target: this is the target variable. target=1 means there are recurring listening event(s) triggered within a month after the user’s very first observable listening event, target=0 otherwise .
#
# #### songs.csv
# * The songs. Note that data is in unicode.
#
# * song_id
# * song_length: in ms
# * genre_ids: genre category. Some songs have multiple genres and they are separated by |
# * artist_name
# * composer
# * lyricist
# * language
#
# #### members.csv
# user information.
# * msno
# * city
# * bd: age. Note: this column has outlier values, please use your judgement.
# * gender
# * registered_via: registration method
# * registration_init_time: format %Y%m%d
# * expiration_date: format %Y%m%d
#
# #### song_extra_info.csv
# * song_id
# * song name - the name of the song.
# * isrc - International Standard Recording Code, theoretically can be used as an identity of a song. However, what worth to note is, ISRCs generated from providers have not been officially verified; therefore the information in ISRC, such as country code and reference year, can be misleading/incorrect. Multiple songs could share one ISRC since a single recording could be re-published several times.
#
# #### sample_submission.csv
# sample submission file in the format that we expect you to submit
#
# * id: same as id in test.csv
# * target: this is the target variable. target=1 means there are recurring listening event(s) triggered within a month after the user’s very first observable listening event, target=0 otherwise.
#
# ### Spotify Data
#
# The Spotify data contains information and audio features of songs in the dataset.
#
# #### dataset
# * track_id: sond id
# * track_name:	Song's title
# * artists: Name of the artist(s)
# * duration_ms: Duration of the song
# * release_date: Date the song was released
# * year: Year of release of the song
# * acousticness: How acoustic the song is
# * danceability: How easy it is to dance to the song
# * energy:	How energetic the song is
# * instrumentalness: How instrumental in nature the song is
# * liveness: How likely it is the song is a live recording
# * loudness: How loud the song is
# * speechiness: How much the song is focused on spoken word
# * tempo: The tempo of the song
# * valence: How positive the mood of the song is
# * mode:
# * key: The musical key the song is played in
# * popularity: Popularity of the song (not a ranking)
# * explicit: Whether the song contains explicit lyrics or not
# * genre: Genre of song

# %% [markdown]
# ### Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# #### Reading the datasets

# %%
train_df = pd.read_csv("data/train.csv")
songs_df = pd.read_csv("data/songs.csv")
members_df = pd.read_csv("data/members.csv")
songs_extra_info_df = pd.read_csv("data/song_extra_info.csv")

# %% [markdown]
# #### Merging the datasets

# %%
t_s_merged = pd.merge(train_df, songs_df, on='song_id', how='left')
t_s_se_merged = pd.merge(t_s_merged, songs_extra_info_df, on='song_id', how='left')
df_kkbox = pd.merge(t_s_se_merged, members_df, on='msno', how='left')

# %% [markdown]
# #### Reading the merged dataset

# %%
df_kkbox.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target  song_length genre_ids  \
# 0              Explore  online-playlist       1     206471.0       359
# 1  Local playlist more   local-playlist       1     284584.0      1259
# 2  Local playlist more   local-playlist       1     225396.0      1259
# 3  Local playlist more   local-playlist       1     255512.0      1019
# 4              Explore  online-playlist       1     187802.0      1011
#
#        artist_name                                 composer lyricist  \
# 0         Bastille                     Dan Smith| Mark Crew      NaN
# 1  Various Artists                                      NaN      NaN
# 2              Nas     N. Jones、W. Adams、J. Lordan、D. Ingle      NaN
# 3         Soundway                            Kwadwo Donkoh      NaN
# 4      Brett Young  Brett Young| Kelly Archer| Justin Ebach      NaN
#
#    language                                     name          isrc  city  bd  \
# 0      52.0                               Good Grief  GBUM71602854     1   0
# 1      52.0                       Lords of Cardboard  US3C69910183    13  24
# 2      52.0  Hip Hop Is Dead(Album Version (Edited))  USUM70618761    13  24
# 3      -1.0                             Disco Africa  GBUQH1000063    13  24
# 4      52.0                        Sleep Without You  QM3E21606003     1   0
#
#    gender  registered_via  registration_init_time  expiration_date
# 0     NaN               7                20120102         20171005
# 1  female               9                20110525         20170911
# 2  female               9                20110525         20170911
# 3  female               9                20110525         20170911
# 4     NaN               7                20120102         20171005

# %% [markdown]
# #### Checking the number of rows and columns

# %%
print('There are', df_kkbox.shape[0], 'rows and', df_kkbox.shape[1], 'columns in the data')
# Out:
# There are 7377418 rows and 20 columns in the data

# %% [markdown]
# #### More information on the data

# %%
df_kkbox.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7377418 entries, 0 to 7377417
# Data columns (total 20 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   msno                    object
#  1   song_id                 object
#  2   source_system_tab       object
#  3   source_screen_name      object
#  4   source_type             object
#  5   target                  int64
#  6   song_length             float64
#  7   genre_ids               object
#  8   artist_name             object
#  9   composer                object
#  10  lyricist                object
#  11  language                float64
#  12  name                    object
#  13  isrc                    object
#  14  city                    int64
#  15  bd                      int64
#  16  gender                  object
#  17  registered_via          int64
#  18  registration_init_time  int64
#  19  expiration_date         int64
# dtypes: float64(2), int64(6), object(12)
# memory usage: 1.2+ GB

# %% [markdown]
# The data types registration_init_time and expiration_date columns are integers instead of datetime, we will address that.

# %% [markdown]
# #### Reading the spotify data

# %%
df_spotify = pd.read_csv("data/spotify_data_1921_to_2020.csv")
df_spotify.head()
# Out:
#                        id                       name   artists  duration_ms  \
# 0  0gNNToCW3qjabgTyBSjt3H  !Que Vida! - Mono Version  ['Love']       220560
# 1  0tMgFpOrXZR6irEOLNWwJL                       "40"    ['U2']       157840
# 2  2ZywW3VyVx6rrlrX75n3JB                "40" - Live    ['U2']       226200
# 3  6DdWA7D1o5TU2kXWyCLcch     "40" - Remastered 2008    ['U2']       157667
# 4  3vMmwsAiLDCfyc1jl76lQE     "40" - Remastered 2008    ['U2']       157667
#
#   release_date  year  acousticness  danceability  energy  instrumentalness  \
# 0      11/1/66  1966        0.5250         0.600   0.540           0.00305
# 1      2/28/83  1983        0.2280         0.368   0.480           0.70700
# 2      8/20/83  1983        0.0998         0.272   0.684           0.01450
# 3      2/28/83  1983        0.1850         0.371   0.545           0.58200
# 4      2/28/83  1983        0.1850         0.371   0.545           0.58200
#
#    liveness  loudness  speechiness    tempo  valence  mode  key  popularity  \
# 0     0.100   -11.803       0.0328  125.898    0.547     1    9          26
# 1     0.159   -11.605       0.0306  150.166    0.338     1    8          21
# 2     0.946    -9.728       0.0505  143.079    0.279     1    8          41
# 3     0.183    -9.315       0.0307  150.316    0.310     1    8          37
# 4     0.183    -9.315       0.0307  150.316    0.310     1    8          35
#
#    explicit
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# #### More information on the spotify data

# %%
df_spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169907 entries, 0 to 169906
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                169907 non-null  object
#  1   name              169907 non-null  object
#  2   artists           169907 non-null  object
#  3   duration_ms       169907 non-null  int64
#  4   release_date      169907 non-null  object
#  5   year              169907 non-null  int64
#  6   acousticness      169907 non-null  float64
#  7   danceability      169907 non-null  float64
#  8   energy            169907 non-null  float64
#  9   instrumentalness  169907 non-null  float64
#  10  liveness          169907 non-null  float64
#  11  loudness          169907 non-null  float64
#  12  speechiness       169907 non-null  float64
#  13  tempo             169907 non-null  float64
#  14  valence           169907 non-null  float64
#  15  mode              169907 non-null  int64
#  16  key               169907 non-null  int64
#  17  popularity        169907 non-null  int64
#  18  explicit          169907 non-null  int64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 24.6+ MB

# %% [markdown]
# **Filtering the Spotify data**

# %%
df_spotify_filtered = df_spotify.loc[(df_spotify['year']>=2004) & (df_spotify['year']<=2016)]

# %%
df_spotify_filtered.head()
# Out:
#                         id                              name  \
# 5   25Sd73fleKUVPNqITPZkn1                              "45"
# 19  3ozivYJGJGq6TSzdy8m64X       "DEVILS NEVER CRY"(スタッフロール)
# 51  3rG8ZkmKHb4Ms6CsSzEITv  "The Take Over, The Breaks Over"
# 52  4zCfMDdf5QXPKEqxdinXvB  "The Take Over, The Breaks Over"
# 60  0P6USuYzHP8GdAyNKLkTZi                          #1 Crush
#
#                     artists  duration_ms release_date  year  acousticness  \
# 5   ['The Gaslight Anthem']       202493       1/1/12  2012      0.000696
# 19    ['Capcom Sound Team']       319907      3/31/05  2005      0.000894
# 51         ['Fall Out Boy']       213587       1/1/07  2007      0.006140
# 52         ['Fall Out Boy']       213587       2/6/07  2007      0.006140
# 60              ['Garbage']       285107       1/1/07  2007      0.000256
#
#     danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 5          0.315   0.970           0.00000    0.2770    -4.709       0.1020
# 19         0.264   0.951           0.04420    0.1270    -7.356       0.1460
# 51         0.609   0.917           0.00002    0.0775    -2.563       0.0477
# 52         0.609   0.917           0.00002    0.0775    -2.563       0.0477
# 60         0.635   0.647           0.00132    0.3580    -7.055       0.0235
#
#       tempo  valence  mode  key  popularity  explicit
# 5   178.068    0.423     1    8          48         0
# 19  149.990    0.159     1    7          49         0
# 51  149.948    0.670     1    9          57         0
# 52  149.948    0.670     1    9          51         0
# 60   94.196    0.464     0    7          41         0

# %% [markdown]
# **Joining the KKBOX and Spotify filtered data**

# %%
df_kkbox_spotify = pd.merge(df_spotify_filtered, df_kkbox, on='name', how='inner')

# %%
pd.set_option('display.max_columns', None)
df_kkbox_spotify.head()
# Out:
#                        id        name                     artists  \
# 0  617KSbx52ACbnQBxSsG26X  #Beautiful  ['Mariah Carey', 'Miguel']
# 1  617KSbx52ACbnQBxSsG26X  #Beautiful  ['Mariah Carey', 'Miguel']
# 2  617KSbx52ACbnQBxSsG26X  #Beautiful  ['Mariah Carey', 'Miguel']
# 3  617KSbx52ACbnQBxSsG26X  #Beautiful  ['Mariah Carey', 'Miguel']
# 4  617KSbx52ACbnQBxSsG26X  #Beautiful  ['Mariah Carey', 'Miguel']
#
#    duration_ms release_date  year  acousticness  danceability  energy  \
# 0       199867      5/27/14  2014         0.346         0.677   0.749
# 1       199867      5/27/14  2014         0.346         0.677   0.749
# 2       199867      5/27/14  2014         0.346         0.677   0.749
# 3       199867      5/27/14  2014         0.346         0.677   0.749
# 4       199867      5/27/14  2014         0.346         0.677   0.749
#
#    instrumentalness  liveness  loudness  speechiness    tempo  valence  mode  \
# 0               0.0     0.347    -5.405       0.0391  107.042    0.469     1
# 1               0.0     0.347    -5.405       0.0391  107.042    0.469     1
# 2               0.0     0.347    -5.405       0.0391  107.042    0.469     1
# 3               0.0     0.347    -5.405       0.0391  107.042    0.469     1
# 4               0.0     0.347    -5.405       0.0391  107.042    0.469     1
#
#    key  popularity  explicit                                          msno  \
# 0    4          54         0  LmCPb0h/s7H7s+Wmb5JwRwJTbasi85lneTR85TXW6DY=
# 1    4          54         0  0eQZY/YLb+YGy3XCo6Q1PP1wQGO7wNuBI8mDGS7/NqQ=
# 2    4          54         0  NMjW8qxMk/ojwFH12PXQmwEsP48/c3rLi7MWU2QHa7k=
# 3    4          54         0  CNviohuVgv0rl0YC+b49AFL2UiB01ZNijpkJRzRfuOI=
# 4    4          54         0  Xa3bbIsP+DO7sQdTiljlnXoiRJl6JXU5xDe9y3HG6Lc=
#
#                                         song_id source_system_tab  \
# 0  WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=            search
# 1  WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=        my library
# 2  lpC0aGdS6Z1I54mHyU7skZt9NalF9lkr531OlEI9AHY=        my library
# 3  WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=        my library
# 4  WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=        my library
#
#     source_screen_name          source_type  target  song_length genre_ids  \
# 0          Artist more  top-hits-for-artist       0     202570.0       465
# 1  Local playlist more       local-playlist       1     202570.0       465
# 2  Local playlist more        local-library       0     199784.0       465
# 3  Local playlist more        local-library       0     202570.0       465
# 4  Local playlist more        local-library       0     202570.0       465
#
#     artist_name                                           composer lyricist  \
# 0  Mariah Carey  Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN
# 1  Mariah Carey  Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN
# 2  Mariah Carey  Miguel Pimentel|Mariah Carey|Nathan Perez|Broo...      NaN
# 3  Mariah Carey  Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN
# 4  Mariah Carey  Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN
#
#    language          isrc  city  bd  gender  registered_via  \
# 0      52.0  USUM71305567     9  33    male               7
# 1      52.0  USUM71305567    22  32  female               9
# 2      52.0  USUM71305567    13  24    male               3
# 3      52.0  USUM71305567     1   0     NaN               7
# 4      52.0  USUM71305567     5  31    male               9
#
#    registration_init_time  expiration_date
# 0                20140729         20170930
# 1                20060303         20180819
# 2                20130903         20171002
# 3                20120118         20171004
# 4                20150705         20180111

# %% [markdown]
# **Removing the special characters in the name and artists column values**

# %%
df_kkbox_spotify['name'] = df_kkbox_spotify['name'].str.replace('#', '')
df_kkbox_spotify['artists'] = df_kkbox_spotify['artists'].str.replace("[", '')
df_kkbox_spotify['artists'] = df_kkbox_spotify['artists'].str.replace("]", '')
df_kkbox_spotify['artists'] = df_kkbox_spotify['artists'].str.replace("'", '')

# %%
# changing the delimiter in the artists column values
df_kkbox_spotify['artists'] = df_kkbox_spotify['artists'].str.replace(",", '|')

# %% [markdown]
# **Renaming columns**

# %%
column_mapping = {'id':'track_id',
                  'name':'track_name',
                 'bd': 'age',
                 'msno':'user_id'}

df_kkbox_spotify = df_kkbox_spotify.rename(columns=column_mapping)

# %%
df_kkbox_spotify.head()
# Out:
#                  track_id track_name               artists  duration_ms  \
# 0  617KSbx52ACbnQBxSsG26X  Beautiful  Mariah Carey| Miguel       199867
# 1  617KSbx52ACbnQBxSsG26X  Beautiful  Mariah Carey| Miguel       199867
# 2  617KSbx52ACbnQBxSsG26X  Beautiful  Mariah Carey| Miguel       199867
# 3  617KSbx52ACbnQBxSsG26X  Beautiful  Mariah Carey| Miguel       199867
# 4  617KSbx52ACbnQBxSsG26X  Beautiful  Mariah Carey| Miguel       199867
#
#   release_date  year  acousticness  danceability  energy  instrumentalness  \
# 0      5/27/14  2014         0.346         0.677   0.749               0.0
# 1      5/27/14  2014         0.346         0.677   0.749               0.0
# 2      5/27/14  2014         0.346         0.677   0.749               0.0
# 3      5/27/14  2014         0.346         0.677   0.749               0.0
# 4      5/27/14  2014         0.346         0.677   0.749               0.0
#
#    liveness  loudness  speechiness    tempo  valence  mode  key  popularity  \
# 0     0.347    -5.405       0.0391  107.042    0.469     1    4          54
# 1     0.347    -5.405       0.0391  107.042    0.469     1    4          54
# 2     0.347    -5.405       0.0391  107.042    0.469     1    4          54
# 3     0.347    -5.405       0.0391  107.042    0.469     1    4          54
# 4     0.347    -5.405       0.0391  107.042    0.469     1    4          54
#
#    explicit                                       user_id  \
# 0         0  LmCPb0h/s7H7s+Wmb5JwRwJTbasi85lneTR85TXW6DY=
# 1         0  0eQZY/YLb+YGy3XCo6Q1PP1wQGO7wNuBI8mDGS7/NqQ=
# 2         0  NMjW8qxMk/ojwFH12PXQmwEsP48/c3rLi7MWU2QHa7k=
# 3         0  CNviohuVgv0rl0YC+b49AFL2UiB01ZNijpkJRzRfuOI=
# 4         0  Xa3bbIsP+DO7sQdTiljlnXoiRJl6JXU5xDe9y3HG6Lc=
#
#                                         song_id source_system_tab  \
# 0  WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=            search
# 1  WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=        my library
# 2  lpC0aGdS6Z1I54mHyU7skZt9NalF9lkr531OlEI9AHY=        my library
# 3  WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=        my library
# 4  WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=        my library
#
#     source_screen_name          source_type  target  song_length genre_ids  \
# 0          Artist more  top-hits-for-artist       0     202570.0       465
# 1  Local playlist more       local-playlist       1     202570.0       465
# 2  Local playlist more        local-library       0     199784.0       465
# 3  Local playlist more        local-library       0     202570.0       465
# 4  Local playlist more        local-library       0     202570.0       465
#
#     artist_name                                           composer lyricist  \
# 0  Mariah Carey  Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN
# 1  Mariah Carey  Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN
# 2  Mariah Carey  Miguel Pimentel|Mariah Carey|Nathan Perez|Broo...      NaN
# 3  Mariah Carey  Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN
# 4  Mariah Carey  Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN
#
#    language          isrc  city  age  gender  registered_via  \
# 0      52.0  USUM71305567     9   33    male               7
# 1      52.0  USUM71305567    22   32  female               9
# 2      52.0  USUM71305567    13   24    male               3
# 3      52.0  USUM71305567     1    0     NaN               7
# 4      52.0  USUM71305567     5   31    male               9
#
#    registration_init_time  expiration_date
# 0                20140729         20170930
# 1                20060303         20180819
# 2                20130903         20171002
# 3                20120118         20171004
# 4                20150705         20180111

# %%
df_kkbox_spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3055369 entries, 0 to 3055368
# Data columns (total 38 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   track_id                object
#  1   track_name              object
#  2   artists                 object
#  3   duration_ms             int64
#  4   release_date            object
#  5   year                    int64
#  6   acousticness            float64
#  7   danceability            float64
#  8   energy                  float64
#  9   instrumentalness        float64
#  10  liveness                float64
#  11  loudness                float64
#  12  speechiness             float64
#  13  tempo                   float64
#  14  valence                 float64
#  15  mode                    int64
#  16  key                     int64
#  17  popularity              int64
#  18  explicit                int64
#  19  user_id                 object
#  20  song_id                 object
#  21  source_system_tab       object
#  22  source_screen_name      object
#  23  source_type             object
#  24  target                  int64
#  25  song_length             float64
#  26  genre_ids               object
#  27  artist_name             object
#  28  composer                object
#  29  lyricist                object
#  30  language                float64
#  31  isrc                    object
#  32  city                    int64
#  33  age                     int64
#  34  gender                  object
#  35  registered_via          int64
#  36  registration_init_time  int64
#  37  expiration_date         int64
# dtypes: float64(11), int64(12), object(15)
# memory usage: 909.1+ MB

# %% [markdown]
# ### Statistical summary of the data

# %%
df_kkbox_spotify.describe(include='all').T
# Out:
#                             count unique  \
# track_id                  3055369  12957
# track_name                3055369   9873
# artists                   3055369   4883
# duration_ms             3055369.0    NaN
# release_date              3055369   1956
# year                    3055369.0    NaN
# acousticness            3055369.0    NaN
# danceability            3055369.0    NaN
# energy                  3055369.0    NaN
# instrumentalness        3055369.0    NaN
# liveness                3055369.0    NaN
# loudness                3055369.0    NaN
# speechiness             3055369.0    NaN
# tempo                   3055369.0    NaN
# valence                 3055369.0    NaN
# mode                    3055369.0    NaN
# key                     3055369.0    NaN
# popularity              3055369.0    NaN
# explicit                3055369.0    NaN
# user_id                   3055369  27029
# song_id                   3055369  46822
# source_system_tab         3045563      8
# source_screen_name        2909873     20
# source_type               3046997     12
# target                  3055369.0    NaN
# song_length             3055358.0    NaN
# genre_ids                 3030248    278
# artist_name               3055358  10997
# composer                  2382991  16531
# lyricist                  1164641   5714
# language                3055358.0    NaN
# isrc                      3007739  37564
# city                    3055369.0    NaN
# age                     3055369.0    NaN
# gender                    1808012      2
# registered_via          3055369.0    NaN
# registration_init_time  3055369.0    NaN
# expiration_date         3055369.0    NaN
#
#                                                                       top  \
# track_id                                           7crMiinWx373rNBZBaVske
# track_name                                                         Closer
# artists                                                      Taylor Swift
# duration_ms                                                           NaN
# release_date                                                       1/1/12
# year                                                                  NaN
# acousticness                                                          NaN
# danceability                                                          NaN
# energy                                                                NaN
# instrumentalness                                                      NaN
# liveness                                                              NaN
# loudness                                                              NaN
# speechiness                                                           NaN
# tempo                                                                 NaN
# valence                                                               NaN
# mode                                                                  NaN
# key                                                                   NaN
# popularity                                                            NaN
# explicit                                                              NaN
# user_id                      o+5RNlSWrzvrphgBNGIo1FLkGxBgyICns6qXj3nS7Pk=
# song_id                      v/3onppBGoSpGsWb8iaCIO8eX5+iacbH5a4ZUhT7N54=
# source_system_tab                                              my library
# source_screen_name                                    Local playlist more
# source_type                                               online-playlist
# target                                                                NaN
# song_length                                                           NaN
# genre_ids                                                             465
# artist_name                                              The Chainsmokers
# composer                Andrew Taggart| Shaun Frank| Frederic Kennett|...
# lyricist                Andrew Taggart| Shaun Frank| Frederic Kennett|...
# language                                                              NaN
# isrc                                                         USQX91601347
# city                                                                  NaN
# age                                                                   NaN
# gender                                                               male
# registered_via                                                        NaN
# registration_init_time                                                NaN
# expiration_date                                                       NaN
#
#                            freq             mean           std         min  \
# track_id                  15149              NaN           NaN         NaN
# track_name               136341              NaN           NaN         NaN
# artists                   77397              NaN           NaN         NaN
# duration_ms                 NaN    239880.856529   55043.40575     30301.0
# release_date              87933              NaN           NaN         NaN
# year                        NaN      2011.490323       3.74372      2004.0
# acousticness                NaN         0.231674      0.278303    0.000002
# danceability                NaN         0.591012      0.145389         0.0
# energy                      NaN         0.658484      0.204604     0.00002
# instrumentalness            NaN         0.045269      0.172773         0.0
# liveness                    NaN         0.175466       0.13306     0.00967
# loudness                    NaN        -6.463737      3.006265     -41.766
# speechiness                 NaN          0.07493      0.075291         0.0
# tempo                       NaN       121.722085     27.908116         0.0
# valence                     NaN         0.445689      0.225863         0.0
# mode                        NaN         0.660276      0.473616         0.0
# key                         NaN          5.21274       3.59146         0.0
# popularity                  NaN        59.027709     10.263706        35.0
# explicit                    NaN         0.172575      0.377879         0.0
# user_id                    3276              NaN           NaN         NaN
# song_id                   97360              NaN           NaN         NaN
# source_system_tab       1511526              NaN           NaN         NaN
# source_screen_name      1351952              NaN           NaN         NaN
# source_type             1022491              NaN           NaN         NaN
# target                      NaN         0.537146      0.498618         0.0
# song_length                 NaN    227201.517613  42826.458437      4685.0
# genre_ids               1201958              NaN           NaN         NaN
# artist_name              178002              NaN           NaN         NaN
# composer                 127863              NaN           NaN         NaN
# lyricist                 127863              NaN           NaN         NaN
# language                    NaN        42.189967     16.919731        -1.0
# isrc                     102258              NaN           NaN         NaN
# city                        NaN         7.354015      6.602738         1.0
# age                         NaN        16.905726     19.645739       -43.0
# gender                   924625              NaN           NaN         NaN
# registered_via              NaN         6.746554      2.289043         3.0
# registration_init_time      NaN  20129080.410426  29798.431591  20040326.0
# expiration_date             NaN  20171488.418595   3972.402103  20041016.0
#
#                                25%         50%         75%         max
# track_id                       NaN         NaN         NaN         NaN
# track_name                     NaN         NaN         NaN         NaN
# artists                        NaN         NaN         NaN         NaN
# duration_ms               208067.0    232520.0    261114.0    975267.0
# release_date                   NaN         NaN         NaN         NaN
# year                        2008.0      2012.0      2015.0      2016.0
# acousticness                0.0153      0.0935       0.395       0.996
# danceability                 0.499       0.602       0.696       0.986
# energy                       0.519       0.696       0.819       0.999
# instrumentalness               0.0    0.000001     0.00016       0.999
# liveness                    0.0955       0.119       0.209        0.99
# loudness                    -7.775      -5.831      -4.473       0.496
# speechiness                 0.0337      0.0457      0.0824       0.936
# tempo                       99.539     120.032     139.091     220.075
# valence                      0.263       0.424       0.614       0.983
# mode                           0.0         1.0         1.0         1.0
# key                            2.0         5.0         8.0        11.0
# popularity                    51.0        58.0        66.0        92.0
# explicit                       0.0         0.0         0.0         1.0
# user_id                        NaN         NaN         NaN         NaN
# song_id                        NaN         NaN         NaN         NaN
# source_system_tab              NaN         NaN         NaN         NaN
# source_screen_name             NaN         NaN         NaN         NaN
# source_type                    NaN         NaN         NaN         NaN
# target                         0.0         1.0         1.0         1.0
# song_length               204382.0    224896.0    244976.0   3239926.0
# genre_ids                      NaN         NaN         NaN         NaN
# artist_name                    NaN         NaN         NaN         NaN
# composer                       NaN         NaN         NaN         NaN
# lyricist                       NaN         NaN         NaN         NaN
# language                      31.0        52.0        52.0        59.0
# isrc                           NaN         NaN         NaN         NaN
# city                           1.0         5.0        13.0        22.0
# age                            0.0        20.0        28.0      1030.0
# gender                         NaN         NaN         NaN         NaN
# registered_via                 4.0         7.0         9.0        13.0
# registration_init_time  20110802.0  20131202.0  20151101.0  20170131.0
# expiration_date         20170910.0  20170924.0  20171006.0  20201017.0

# %% [markdown]
# * Taylor swift is the most listened to among the artists in the data.
# * Most users have their personal libraries as their preferred source for listening to music.
# * The age column has extreme and unrealistic values with the minimum and maximum being -43 and 1030 respectively. This indicates there are outliers in this column.
# * The average liveness of songs in the data is 0.18 and 75% of all songs have a liveness of 0.21, showing the dominance of electronic music.
# * 75% of songs have speechiness of approximately 0.1 showing that most songs are not very heavy on words.

# %% [markdown]
# ### Outlier treatment

# %% [markdown]
# **Checking outliers using z-score**

# %%
mean_of_age = np.mean(df_kkbox_spotify['age']) 
mode_of_age = df_kkbox_spotify['age'].mode()[0]
std_of_age = np.std(df_kkbox_spotify['age'])
print("Mean of Age: ",mean_of_age)
print("Mode of Age: ",mode_of_age)
print("Standard Deviation of Age: ",std_of_age)

threshold = 3
outlier = [] 
for i in df_kkbox_spotify['age']: 
    z = (i-mean_of_age)/std_of_age
    if z > threshold: 
        outlier.append(i) 
print('Total outliers in the column: ', len(outlier))
print("Maximum Age Outlier: ", max(outlier))
print("Minimum Age Outlier: ", min(outlier))
# Out:
# Mean of Age:  16.905725625939127
# Mode of Age:  0
# Standard Deviation of Age:  19.64573608114557
# Total outliers in the column:  3139
# Maximum Age Outlier:  1030
# Minimum Age Outlier:  78

# %% [markdown]
# * There are a total of 3139 outliers in the bd column
# * Ages between 78 and 1030 are outliers and can be removed

# %% [markdown]
# **Removing outliers in age column**

# %%
df_kkbox_spotify.drop(df_kkbox_spotify[df_kkbox_spotify['age'] > 80].index, inplace = True)
df_kkbox_spotify.drop(df_kkbox_spotify[df_kkbox_spotify['age'] <=0].index, inplace = True)

# %% [markdown]
# ### Checking for Missing Values

# %%
print("Total Null values in the dataset:\n", df_kkbox_spotify.isnull().sum())
# Out:
# Total Null values in the dataset:
#  track_id                        0
# track_name                      0
# artists                         0
# duration_ms                     0
# release_date                    0
# year                            0
# acousticness                    0
# danceability                    0
# energy                          0
# instrumentalness                0
# liveness                        0
# loudness                        0
# speechiness                     0
# tempo                           0
# valence                         0
# mode                            0
# key                             0
# popularity                      0
# explicit                        0
# user_id                         0
# song_id                         0
# source_system_tab            6697
# source_screen_name          81468
# source_type                  5275
# target                          0
# song_length                     4
# genre_ids                   14905
# artist_name                     4
# composer                   401701
# lyricist                  1130385
# language                        4
# isrc                        27519
# city                            0
# age                             0
# gender                      60252
# registered_via                  0
# registration_init_time          0
# expiration_date                 0
# dtype: int64

# %% [markdown]
# ### Handling missing values

# %% [markdown]
# **Checking the percentage of missing values for the columns in question**

# %%
percentage_missing = df_kkbox_spotify.isnull().sum() * 100 / len(df_kkbox_spotify)
percentage_missing
# Out:
# track_id                   0.000000
# track_name                 0.000000
# artists                    0.000000
# duration_ms                0.000000
# release_date               0.000000
# year                       0.000000
# acousticness               0.000000
# danceability               0.000000
# energy                     0.000000
# instrumentalness           0.000000
# liveness                   0.000000
# loudness                   0.000000
# speechiness                0.000000
# tempo                      0.000000
# valence                    0.000000
# mode                       0.000000
# key                        0.000000
# popularity                 0.000000
# explicit                   0.000000
# user_id                    0.000000
# song_id                    0.000000
# source_system_tab          0.369503
# source_screen_name         4.494950
# source_type                0.291045
# target                     0.000000
# song_length                0.000221
# genre_ids                  0.822375
# artist_name                0.000221
# composer                  22.163621
# lyricist                  62.368340
# language                   0.000221
# isrc                       1.518345
# city                       0.000000
# age                        0.000000
# gender                     3.324369
# registered_via             0.000000
# registration_init_time     0.000000
# expiration_date            0.000000
# dtype: float64

# %% [markdown]
# lyricist has the highest percentage of missing values with 62.4%, followed by composer and source screen name which have 22.2% and 4.5% respectively

# %%
# extracting all the information of other columns where lyricist is null
df_kkbox_spotify.loc[df_kkbox_spotify['lyricist'].isnull()==True]
# Out:
#                        track_id                   track_name  \
# 0        617KSbx52ACbnQBxSsG26X                    Beautiful
# 1        617KSbx52ACbnQBxSsG26X                    Beautiful
# 2        617KSbx52ACbnQBxSsG26X                    Beautiful
# 4        617KSbx52ACbnQBxSsG26X                    Beautiful
# 5        617KSbx52ACbnQBxSsG26X                    Beautiful
# ...                         ...                          ...
# 3055359  4mwzUFtpBHJVyBs16YjjPN  몸매 Mommae (feat. Ugly Duck)
# 3055362  4mwzUFtpBHJVyBs16YjjPN  몸매 Mommae (feat. Ugly Duck)
# 3055364  4mwzUFtpBHJVyBs16YjjPN  몸매 Mommae (feat. Ugly Duck)
# 3055365  4mwzUFtpBHJVyBs16YjjPN  몸매 Mommae (feat. Ugly Duck)
# 3055368  4mwzUFtpBHJVyBs16YjjPN  몸매 Mommae (feat. Ugly Duck)
#
#                       artists  duration_ms release_date  year  acousticness  \
# 0        Mariah Carey| Miguel       199867      5/27/14  2014         0.346
# 1        Mariah Carey| Miguel       199867      5/27/14  2014         0.346
# 2        Mariah Carey| Miguel       199867      5/27/14  2014         0.346
# 4        Mariah Carey| Miguel       199867      5/27/14  2014         0.346
# 5        Mariah Carey| Miguel       199867      5/27/14  2014         0.346
# ...                       ...          ...          ...   ...           ...
# 3055359   Jay Park| Ugly Duck       204327      11/5/15  2015         0.218
# 3055362   Jay Park| Ugly Duck       204327      11/5/15  2015         0.218
# 3055364   Jay Park| Ugly Duck       204327      11/5/15  2015         0.218
# 3055365   Jay Park| Ugly Duck       204327      11/5/15  2015         0.218
# 3055368   Jay Park| Ugly Duck       204327      11/5/15  2015         0.218
#
#          danceability  energy  instrumentalness  liveness  loudness  \
# 0               0.677   0.749               0.0     0.347    -5.405
# 1               0.677   0.749               0.0     0.347    -5.405
# 2               0.677   0.749               0.0     0.347    -5.405
# 4               0.677   0.749               0.0     0.347    -5.405
# 5               0.677   0.749               0.0     0.347    -5.405
# ...               ...     ...               ...       ...       ...
# 3055359         0.745   0.669               0.0     0.104    -5.362
# 3055362         0.745   0.669               0.0     0.104    -5.362
# 3055364         0.745   0.669               0.0     0.104    -5.362
# 3055365         0.745   0.669               0.0     0.104    -5.362
# 3055368         0.745   0.669               0.0     0.104    -5.362
#
#          speechiness    tempo  valence  mode  key  popularity  explicit  \
# 0             0.0391  107.042    0.469     1    4          54         0
# 1             0.0391  107.042    0.469     1    4          54         0
# 2             0.0391  107.042    0.469     1    4          54         0
# 4             0.0391  107.042    0.469     1    4          54         0
# 5             0.0391  107.042    0.469     1    4          54         0
# ...              ...      ...      ...   ...  ...         ...       ...
# 3055359       0.2420   94.089    0.681     0    9          59         0
# 3055362       0.2420   94.089    0.681     0    9          59         0
# 3055364       0.2420   94.089    0.681     0    9          59         0
# 3055365       0.2420   94.089    0.681     0    9          59         0
# 3055368       0.2420   94.089    0.681     0    9          59         0
#
#                                               user_id  \
# 0        LmCPb0h/s7H7s+Wmb5JwRwJTbasi85lneTR85TXW6DY=
# 1        0eQZY/YLb+YGy3XCo6Q1PP1wQGO7wNuBI8mDGS7/NqQ=
# 2        NMjW8qxMk/ojwFH12PXQmwEsP48/c3rLi7MWU2QHa7k=
# 4        Xa3bbIsP+DO7sQdTiljlnXoiRJl6JXU5xDe9y3HG6Lc=
# 5        XxutbW66gZOkdhrVis6UO4jrdZwM+nsEMoImbiNxhbw=
# ...                                               ...
# 3055359  lXNHSz6MZLPEWQBzUhR07mSvff9jqm7DhdMZ7+PUfMA=
# 3055362  E0nBZsee6bvHLEAQZWTMst/NzbbsIzpNjFR+WOBoii4=
# 3055364  0qi7dNxPOGVxhhb7HCc4MeY5AA5p98/7C2OD2GzP9+o=
# 3055365  cc+EAeS+ruyrnjzOszFQx/2isjGX55hBgH9Kbl3sols=
# 3055368  5zsCViormTqlJqRLlFV0FcY8WurOHbOpGTHEIYzegAc=
#
#                                               song_id source_system_tab  \
# 0        WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=            search
# 1        WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=        my library
# 2        lpC0aGdS6Z1I54mHyU7skZt9NalF9lkr531OlEI9AHY=        my library
# 4        WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=        my library
# 5        WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=        my library
# ...                                               ...               ...
# 3055359  ZJ9CTew7zV0l9B2tFWJ1Qiyj+viPLiqxCmYO6+I25BE=          discover
# 3055362  ZJ9CTew7zV0l9B2tFWJ1Qiyj+viPLiqxCmYO6+I25BE=          discover
# 3055364  ZJ9CTew7zV0l9B2tFWJ1Qiyj+viPLiqxCmYO6+I25BE=        my library
# 3055365  ZJ9CTew7zV0l9B2tFWJ1Qiyj+viPLiqxCmYO6+I25BE=        my library
# 3055368  ZJ9CTew7zV0l9B2tFWJ1Qiyj+viPLiqxCmYO6+I25BE=            search
#
#           source_screen_name          source_type  target  song_length  \
# 0                Artist more  top-hits-for-artist       0     202570.0
# 1        Local playlist more       local-playlist       1     202570.0
# 2        Local playlist more        local-library       0     199784.0
# 4        Local playlist more        local-library       0     202570.0
# 5        Local playlist more        local-library       0     202570.0
# ...                      ...                  ...     ...          ...
# 3055359     Discover Feature      online-playlist       0     204277.0
# 3055362                  NaN  top-hits-for-artist       1     204277.0
# 3055364  Local playlist more       local-playlist       0     204277.0
# 3055365  Local playlist more       local-playlist       0     204277.0
# 3055368               Search                 song       1     204277.0
#
#         genre_ids   artist_name  \
# 0             465  Mariah Carey
# 1             465  Mariah Carey
# 2             465  Mariah Carey
# 4             465  Mariah Carey
# 5             465  Mariah Carey
# ...           ...           ...
# 3055359      1259      Jay Park
# 3055362      1259      Jay Park
# 3055364      1259      Jay Park
# 3055365      1259      Jay Park
# 3055368      1259      Jay Park
#
#                                                   composer lyricist  language  \
# 0        Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN      52.0
# 1        Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN      52.0
# 2        Miguel Pimentel|Mariah Carey|Nathan Perez|Broo...      NaN      52.0
# 4        Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN      52.0
# 5        Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN      52.0
# ...                                                    ...      ...       ...
# 3055359                                                NaN      NaN      31.0
# 3055362                                                NaN      NaN      31.0
# 3055364                                                NaN      NaN      31.0
# 3055365                                                NaN      NaN      31.0
# 3055368                                                NaN      NaN      31.0
#
#                  isrc  city  age  gender  registered_via  \
# 0        USUM71305567     9   33    male               7
# 1        USUM71305567    22   32  female               9
# 2        USUM71305567    13   24    male               3
# 4        USUM71305567     5   31    male               9
# 5        USUM71305567    13   27  female               7
# ...               ...   ...  ...     ...             ...
# 3055359  KRA351505941    13   27    male               9
# 3055362  KRA351505941    13   21    male               3
# 3055364  KRA351505941     5   27    male               4
# 3055365  KRA351505941    11   24    male               9
# 3055368  KRA351505941     5   19  female               9
#
#          registration_init_time  expiration_date
# 0                      20140729         20170930
# 1                      20060303         20180819
# 2                      20130903         20171002
# 4                      20150705         20180111
# 5                      20120109         20170919
# ...                         ...              ...
# 3055359                20090120         20170923
# 3055362                20120118         20180604
# 3055364                20151221         20171215
# 3055365                20060709         20170707
# 3055368                20100718         20170922
#
# [1130385 rows x 38 columns]

# %%
# extracting all the information of other columns where composer is null
df_kkbox_spotify.loc[df_kkbox_spotify['composer'].isnull()==True]
# Out:
#                        track_id                   track_name  \
# 52       617KSbx52ACbnQBxSsG26X                    Beautiful
# 75       617KSbx52ACbnQBxSsG26X                    Beautiful
# 96       617KSbx52ACbnQBxSsG26X                    Beautiful
# 107      617KSbx52ACbnQBxSsG26X                    Beautiful
# 144      1HOlb9rdNOmy9b1Fakicjo                       SELFIE
# ...                         ...                          ...
# 3055359  4mwzUFtpBHJVyBs16YjjPN  몸매 Mommae (feat. Ugly Duck)
# 3055362  4mwzUFtpBHJVyBs16YjjPN  몸매 Mommae (feat. Ugly Duck)
# 3055364  4mwzUFtpBHJVyBs16YjjPN  몸매 Mommae (feat. Ugly Duck)
# 3055365  4mwzUFtpBHJVyBs16YjjPN  몸매 Mommae (feat. Ugly Duck)
# 3055368  4mwzUFtpBHJVyBs16YjjPN  몸매 Mommae (feat. Ugly Duck)
#
#                       artists  duration_ms release_date  year  acousticness  \
# 52       Mariah Carey| Miguel       199867      5/27/14  2014        0.3460
# 75       Mariah Carey| Miguel       199867      5/27/14  2014        0.3460
# 96       Mariah Carey| Miguel       199867      5/27/14  2014        0.3460
# 107      Mariah Carey| Miguel       199867      5/27/14  2014        0.3460
# 144          The Chainsmokers       183750       1/1/14  2014        0.0135
# ...                       ...          ...          ...   ...           ...
# 3055359   Jay Park| Ugly Duck       204327      11/5/15  2015        0.2180
# 3055362   Jay Park| Ugly Duck       204327      11/5/15  2015        0.2180
# 3055364   Jay Park| Ugly Duck       204327      11/5/15  2015        0.2180
# 3055365   Jay Park| Ugly Duck       204327      11/5/15  2015        0.2180
# 3055368   Jay Park| Ugly Duck       204327      11/5/15  2015        0.2180
#
#          danceability  energy  instrumentalness  liveness  loudness  \
# 52              0.677   0.749          0.000000     0.347    -5.405
# 75              0.677   0.749          0.000000     0.347    -5.405
# 96              0.677   0.749          0.000000     0.347    -5.405
# 107             0.677   0.749          0.000000     0.347    -5.405
# 144             0.789   0.916          0.000008     0.077    -3.262
# ...               ...     ...               ...       ...       ...
# 3055359         0.745   0.669          0.000000     0.104    -5.362
# 3055362         0.745   0.669          0.000000     0.104    -5.362
# 3055364         0.745   0.669          0.000000     0.104    -5.362
# 3055365         0.745   0.669          0.000000     0.104    -5.362
# 3055368         0.745   0.669          0.000000     0.104    -5.362
#
#          speechiness    tempo  valence  mode  key  popularity  explicit  \
# 52            0.0391  107.042    0.469     1    4          54         0
# 75            0.0391  107.042    0.469     1    4          54         0
# 96            0.0391  107.042    0.469     1    4          54         0
# 107           0.0391  107.042    0.469     1    4          54         0
# 144           0.2490  127.956    0.658     1    0          64         0
# ...              ...      ...      ...   ...  ...         ...       ...
# 3055359       0.2420   94.089    0.681     0    9          59         0
# 3055362       0.2420   94.089    0.681     0    9          59         0
# 3055364       0.2420   94.089    0.681     0    9          59         0
# 3055365       0.2420   94.089    0.681     0    9          59         0
# 3055368       0.2420   94.089    0.681     0    9          59         0
#
#                                               user_id  \
# 52       BNSYbtaNNCYfKVig95LpQJArTEx/RN2FgivSohB8r8M=
# 75       j7cLJrPb1q69WPcysoOo/PtMRYwtDHXQyYaHF9zHQmQ=
# 96       DbAOLMcNxZ18DITwNfCMq5Fl0NbiINmmLbZp8KXiuOo=
# 107      crUeQ6DYDHHRNYmn+n5Kodfvu9ki0IdHfXHNlZEUPHs=
# 144      6v8Jemjp+1m3F1R8PILMTByss6WHHr7IzJqle4RUrdo=
# ...                                               ...
# 3055359  lXNHSz6MZLPEWQBzUhR07mSvff9jqm7DhdMZ7+PUfMA=
# 3055362  E0nBZsee6bvHLEAQZWTMst/NzbbsIzpNjFR+WOBoii4=
# 3055364  0qi7dNxPOGVxhhb7HCc4MeY5AA5p98/7C2OD2GzP9+o=
# 3055365  cc+EAeS+ruyrnjzOszFQx/2isjGX55hBgH9Kbl3sols=
# 3055368  5zsCViormTqlJqRLlFV0FcY8WurOHbOpGTHEIYzegAc=
#
#                                               song_id source_system_tab  \
# 52       yntlgMUHpX/6+TN/MUrIAIodp52QAMaMb+eFRBrEOV0=          discover
# 75       yntlgMUHpX/6+TN/MUrIAIodp52QAMaMb+eFRBrEOV0=        my library
# 96       yntlgMUHpX/6+TN/MUrIAIodp52QAMaMb+eFRBrEOV0=          discover
# 107      yntlgMUHpX/6+TN/MUrIAIodp52QAMaMb+eFRBrEOV0=        my library
# 144      Mk3+/7Emj9HBT8NcLyjXPQGM7vqqIbVwyIH/rjWNUqg=          discover
# ...                                               ...               ...
# 3055359  ZJ9CTew7zV0l9B2tFWJ1Qiyj+viPLiqxCmYO6+I25BE=          discover
# 3055362  ZJ9CTew7zV0l9B2tFWJ1Qiyj+viPLiqxCmYO6+I25BE=          discover
# 3055364  ZJ9CTew7zV0l9B2tFWJ1Qiyj+viPLiqxCmYO6+I25BE=        my library
# 3055365  ZJ9CTew7zV0l9B2tFWJ1Qiyj+viPLiqxCmYO6+I25BE=        my library
# 3055368  ZJ9CTew7zV0l9B2tFWJ1Qiyj+viPLiqxCmYO6+I25BE=            search
#
#            source_screen_name          source_type  target  song_length  \
# 52       Online playlist more  song-based-playlist       1     200048.0
# 75        Local playlist more        local-library       0     200048.0
# 96       Online playlist more  song-based-playlist       1     200048.0
# 107       Local playlist more        local-library       0     200048.0
# 144            Discover Chart      online-playlist       0     183693.0
# ...                       ...                  ...     ...          ...
# 3055359      Discover Feature      online-playlist       0     204277.0
# 3055362                   NaN  top-hits-for-artist       1     204277.0
# 3055364   Local playlist more       local-playlist       0     204277.0
# 3055365   Local playlist more       local-playlist       0     204277.0
# 3055368                Search                 song       1     204277.0
#
#         genre_ids       artist_name composer lyricist  language          isrc  \
# 52            465      Mariah Carey      NaN      NaN      52.0  USUM71306669
# 75            465      Mariah Carey      NaN      NaN      52.0  USUM71306669
# 96            465      Mariah Carey      NaN      NaN      52.0  USUM71306669
# 107           465      Mariah Carey      NaN      NaN      52.0  USUM71306669
# 144          1609  The Chainsmokers      NaN      NaN      52.0  USDM31400016
# ...           ...               ...      ...      ...       ...           ...
# 3055359      1259          Jay Park      NaN      NaN      31.0  KRA351505941
# 3055362      1259          Jay Park      NaN      NaN      31.0  KRA351505941
# 3055364      1259          Jay Park      NaN      NaN      31.0  KRA351505941
# 3055365      1259          Jay Park      NaN      NaN      31.0  KRA351505941
# 3055368      1259          Jay Park      NaN      NaN      31.0  KRA351505941
#
#          city  age  gender  registered_via  registration_init_time  \
# 52          4   37    male               9                20061115
# 75          4   22    male               9                20140404
# 96         22   37    male               9                20110304
# 107        13   22    male               9                20140614
# 144        15   36    male               9                20150108
# ...       ...  ...     ...             ...                     ...
# 3055359    13   27    male               9                20090120
# 3055362    13   21    male               3                20120118
# 3055364     5   27    male               4                20151221
# 3055365    11   24    male               9                20060709
# 3055368     5   19  female               9                20100718
#
#          expiration_date
# 52              20170920
# 75              20171004
# 96              20171229
# 107             20170907
# 144             20171003
# ...                  ...
# 3055359         20170923
# 3055362         20180604
# 3055364         20171215
# 3055365         20170707
# 3055368         20170922
#
# [401701 rows x 38 columns]

# %%
# extracting all the information of other columns where source_screen_name is null
df_kkbox_spotify.loc[df_kkbox_spotify['source_screen_name'].isnull()==True]
# Out:
#                        track_id                   track_name  \
# 18       617KSbx52ACbnQBxSsG26X                    Beautiful
# 30       617KSbx52ACbnQBxSsG26X                    Beautiful
# 86       617KSbx52ACbnQBxSsG26X                    Beautiful
# 97       617KSbx52ACbnQBxSsG26X                    Beautiful
# 105      617KSbx52ACbnQBxSsG26X                    Beautiful
# ...                         ...                          ...
# 3055305  4mwzUFtpBHJVyBs16YjjPN  몸매 Mommae (feat. Ugly Duck)
# 3055306  4mwzUFtpBHJVyBs16YjjPN  몸매 Mommae (feat. Ugly Duck)
# 3055324  4mwzUFtpBHJVyBs16YjjPN  몸매 Mommae (feat. Ugly Duck)
# 3055352  4mwzUFtpBHJVyBs16YjjPN  몸매 Mommae (feat. Ugly Duck)
# 3055362  4mwzUFtpBHJVyBs16YjjPN  몸매 Mommae (feat. Ugly Duck)
#
#                       artists  duration_ms release_date  year  acousticness  \
# 18       Mariah Carey| Miguel       199867      5/27/14  2014         0.346
# 30       Mariah Carey| Miguel       199867      5/27/14  2014         0.346
# 86       Mariah Carey| Miguel       199867      5/27/14  2014         0.346
# 97       Mariah Carey| Miguel       199867      5/27/14  2014         0.346
# 105      Mariah Carey| Miguel       199867      5/27/14  2014         0.346
# ...                       ...          ...          ...   ...           ...
# 3055305   Jay Park| Ugly Duck       204327      11/5/15  2015         0.218
# 3055306   Jay Park| Ugly Duck       204327      11/5/15  2015         0.218
# 3055324   Jay Park| Ugly Duck       204327      11/5/15  2015         0.218
# 3055352   Jay Park| Ugly Duck       204327      11/5/15  2015         0.218
# 3055362   Jay Park| Ugly Duck       204327      11/5/15  2015         0.218
#
#          danceability  energy  instrumentalness  liveness  loudness  \
# 18              0.677   0.749               0.0     0.347    -5.405
# 30              0.677   0.749               0.0     0.347    -5.405
# 86              0.677   0.749               0.0     0.347    -5.405
# 97              0.677   0.749               0.0     0.347    -5.405
# 105             0.677   0.749               0.0     0.347    -5.405
# ...               ...     ...               ...       ...       ...
# 3055305         0.745   0.669               0.0     0.104    -5.362
# 3055306         0.745   0.669               0.0     0.104    -5.362
# 3055324         0.745   0.669               0.0     0.104    -5.362
# 3055352         0.745   0.669               0.0     0.104    -5.362
# 3055362         0.745   0.669               0.0     0.104    -5.362
#
#          speechiness    tempo  valence  mode  key  popularity  explicit  \
# 18            0.0391  107.042    0.469     1    4          54         0
# 30            0.0391  107.042    0.469     1    4          54         0
# 86            0.0391  107.042    0.469     1    4          54         0
# 97            0.0391  107.042    0.469     1    4          54         0
# 105           0.0391  107.042    0.469     1    4          54         0
# ...              ...      ...      ...   ...  ...         ...       ...
# 3055305       0.2420   94.089    0.681     0    9          59         0
# 3055306       0.2420   94.089    0.681     0    9          59         0
# 3055324       0.2420   94.089    0.681     0    9          59         0
# 3055352       0.2420   94.089    0.681     0    9          59         0
# 3055362       0.2420   94.089    0.681     0    9          59         0
#
#                                               user_id  \
# 18       mHanXIId8t0t4y7YZCdaSwc3/LnnkF/EKOlWy+jNukQ=
# 30       1d4acB2bhEZCFjSRwvO4ls8PrBtvNTlkcAcxYx8FcWE=
# 86       ohnJTn+6M+W0aBR5LMcP8MTTKB7GscEY3zif1vB3Cjc=
# 97       VxVaRlhgqAetKLLBOQR6SKvSp1VbYpQ15HjPAetXjME=
# 105      H/MB+uttGlGIMr7qru4HYG4dVbh0e1mBuoryBOKz/RU=
# ...                                               ...
# 3055305  cIAWv5YOFzHtganCl67btiKdXsGEHMAOUSvGQbhcbC8=
# 3055306  HihZqURxXxAaZN1JI66HV6YuJlGDgp7ZRtHtuBtn+q4=
# 3055324  zYTm2T59lT+Z/hpoywdET+EGMcRhwi4rzL7WD09iRC0=
# 3055352  3TZaybijIyaqU3P+moI/mzFWcAj6aR0p7bmxLT9iRq8=
# 3055362  E0nBZsee6bvHLEAQZWTMst/NzbbsIzpNjFR+WOBoii4=
#
#                                               song_id source_system_tab  \
# 18       WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=          discover
# 30       WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=       listen with
# 86       WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=        my library
# 97       WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=        my library
# 105      WTQo/GJtT2qyQvqTRfsznnW6S63QNi2gDjS9DudG9ik=          discover
# ...                                               ...               ...
# 3055305  ZJ9CTew7zV0l9B2tFWJ1Qiyj+viPLiqxCmYO6+I25BE=        my library
# 3055306  ZJ9CTew7zV0l9B2tFWJ1Qiyj+viPLiqxCmYO6+I25BE=        my library
# 3055324  ZJ9CTew7zV0l9B2tFWJ1Qiyj+viPLiqxCmYO6+I25BE=        my library
# 3055352  ZJ9CTew7zV0l9B2tFWJ1Qiyj+viPLiqxCmYO6+I25BE=               NaN
# 3055362  ZJ9CTew7zV0l9B2tFWJ1Qiyj+viPLiqxCmYO6+I25BE=          discover
#
#         source_screen_name          source_type  target  song_length  \
# 18                     NaN  top-hits-for-artist       0     202570.0
# 30                     NaN          listen-with       0     202570.0
# 86                     NaN  top-hits-for-artist       0     202570.0
# 97                     NaN  top-hits-for-artist       0     202570.0
# 105                    NaN  top-hits-for-artist       0     202570.0
# ...                    ...                  ...     ...          ...
# 3055305                NaN  top-hits-for-artist       0     204277.0
# 3055306                NaN  top-hits-for-artist       1     204277.0
# 3055324                NaN  top-hits-for-artist       0     204277.0
# 3055352                NaN      online-playlist       0     204277.0
# 3055362                NaN  top-hits-for-artist       1     204277.0
#
#         genre_ids   artist_name  \
# 18            465  Mariah Carey
# 30            465  Mariah Carey
# 86            465  Mariah Carey
# 97            465  Mariah Carey
# 105           465  Mariah Carey
# ...           ...           ...
# 3055305      1259      Jay Park
# 3055306      1259      Jay Park
# 3055324      1259      Jay Park
# 3055352      1259      Jay Park
# 3055362      1259      Jay Park
#
#                                                   composer lyricist  language  \
# 18       Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN      52.0
# 30       Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN      52.0
# 86       Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN      52.0
# 97       Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN      52.0
# 105      Mariah Carey| Brook Davis| Miguel Pimentel| Na...      NaN      52.0
# ...                                                    ...      ...       ...
# 3055305                                                NaN      NaN      31.0
# 3055306                                                NaN      NaN      31.0
# 3055324                                                NaN      NaN      31.0
# 3055352                                                NaN      NaN      31.0
# 3055362                                                NaN      NaN      31.0
#
#                  isrc  city  age  gender  registered_via  \
# 18       USUM71305567     6   24    male               9
# 30       USUM71305567     1   27  female               3
# 86       USUM71305567    15   38    male               9
# 97       USUM71305567    13   27  female               9
# 105      USUM71305567     1   25    male               3
# ...               ...   ...  ...     ...             ...
# 3055305  KRA351505941    15   37  female               9
# 3055306  KRA351505941    12   43    male               9
# 3055324  KRA351505941    13   25  female               9
# 3055352  KRA351505941    21   39  female               9
# 3055362  KRA351505941    13   21    male               3
#
#          registration_init_time  expiration_date
# 18                     20150308         20170817
# 30                     20150105         20170630
# 86                     20080729         20170613
# 97                     20111210         20171007
# 105                    20161214         20170928
# ...                         ...              ...
# 3055305                20150817         20170924
# 3055306                20050717         20170930
# 3055324                20130824         20170917
# 3055352                20100414         20170923
# 3055362                20120118         20180604
#
# [81468 rows x 38 columns]

# %% [markdown]
# 1. There's no definite pattern to the missingness of these values so we can either drop the rows with missing values or replace them with the modes.
# 2. Considering the high percentage of missing values in lyricist column it wouldn't make sense to replace the values with mode as we need to be sure who the lyricists are, we will have to drop this column alongside other irrelevant columns.

# %% [markdown]
# **Dropping unnecessary columns**

# %%
df_kkbox_spotify.columns
# Out:
# Index(['track_id', 'track_name', 'artists', 'duration_ms', 'release_date',
#        'year', 'acousticness', 'danceability', 'energy', 'instrumentalness',
#        'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'mode',
#        'key', 'popularity', 'explicit', 'user_id', 'song_id',
#        'source_system_tab', 'source_screen_name', 'source_type', 'target',
#        'song_length', 'genre_ids', 'artist_name', 'composer', 'lyricist',
#        'language', 'isrc', 'city', 'age', 'gender', 'registered_via',
#        'registration_init_time', 'expiration_date'],
#       dtype='object')

# %%
columns_to_drop = ['song_id','song_length','artist_name','composer', 'lyricist', 'isrc', 'city', 'registered_via', 'registration_init_time',
                  'expiration_date']

# %%
df_kkbox_spotify.drop(columns_to_drop, axis=1,inplace=True)

# %%
df_kkbox_spotify.shape
# Out:
# (1812434, 28)

# %% [markdown]
# **Removing null values**

# %%
df_null_removed = df_kkbox_spotify.dropna()
df_null_removed.shape
# Out:
# (1659199, 28)

# %% [markdown]
# **Replacing null values with mode**

# %%
df_mode_replaced = df_kkbox_spotify.copy()
for col in df_mode_replaced.columns:
    df_mode_replaced[col].fillna(df_mode_replaced[col].mode()[0])

# %%
df_mode_replaced.shape
# Out:
# (1812434, 28)
